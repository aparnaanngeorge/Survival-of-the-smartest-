# %%
from sys import exit
import random


print("""
    
    
Introduction:

The game is called 'Survival of the smartest?'. This game is an 
adapted version of the paper-based game called 'Hangman'. The game is simple 
and requires you to guess the letters of the word and reveal it, to 
clear each level without dying. You will be given 8 chances to guess the word 
right.For every wrong guess a part of body is drawn and upon losing all your 
chances will be lost and you will see a man hanged, in other words it means 
you lost your adventure. 

A simple guideline will be to start the game by guessing for vowels
(a, e, i, o, u), and then proceed guessing other letters.
    
    The game has 3 levels 
    a)Level 1 Choose a dangerous path out of two 
    b)Level 2 Choose a challenging cavern out of two 
    c)Level 3 Identify the country and its capital inorder to escape the island safely
    
Upon completion of the levels you shall win this game 
    
""")
global starting

name=''


def starting():
    """Introduces the game to the user and ask their name."""
    global name
    print("_"* 100)
    print("*"* 100)
    #Introducing game to user
    print("""
            Welcome to..'Survival of the smartest'!!
            
            This game is an adapted version of the paper based game called 
            'Hangman'. The game is simple and requires you to guess the letters
            of the word and reveal it inorder to survive each level without dying. 
            You will be given 8 chances to guess the word right.For every wrong
            guess a part of body is drawn and upon losing all your chances will
            be lost and you will see a man hanged, in other words it means you
            lost your adventure.
                          
                             What is your name?
           """)
    name=input(f">>Response:\n")
    print(f"Hello {name} !! Hope you are excited today!\n")
    input(f"<Press Enter to Continue, {name}>")
    startpath()

def hangman(x):
    """ This function is created to print stick figures corresponding to every failed attempt"""
    picture=[]
    picture=[
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                                   
   |                                 
   |                                   
   |                                  
   |                                  
   |                                
   |                               
   |                                    
   |                             
   |                               
   |                                
   |                                  
   |                                  
   |                                 
   |                                 
   |                                 
   |                                  
   |                               
   |                             
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                                  
   |                                
   |                               
   |                                    
   |                             
   |                               
   |                                
   |                                  
   |                                  
   |                                 
   |                                 
   |                                 
   |                                  
   |                               
   |                             
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |                             
   |                               
   |                                
   |                                  
   |                                  
   |                                 
   |                                 
   |                                 
   |                                  
   |                               
   |                             
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |               \                  
   |                \                 
   |                 \               
   |                                  
   |                                  
   |                                   
   |                                   
   |                                  
   |                                 
   |                               
   |                             
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |               \  |                
   |                \ |                
   |                 \|                
   |                  |                 
   |                                   
   |                                   
   |                                   
   |                                  
   |                                  
   |                                
   |                            
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |               \  |                
   |                \ |              
   |                 \|                
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                                  
   |                                
   |                             
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |               \  |  /              
   |                \ | /               
   |                 \|/                
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                                 
   |                                
   |                              
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
    
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |               \  |  /              
   |                \ | /               
   |                 \|/                
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                 /                 
   |                /                  
   |               /                   
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

""",
"""                                    
                   __                   
      |__| /\ |\ |/ _`|\/| /\ |\ |      
      |  |/~~\| \|\__>|  |/~~\| \|      
                                                                
   ____________________________________ 
                                        
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                   __               
   |                  /  \              
   |                  \__/              
   |                                    
   |               \  |  /              
   |                \ | /               
   |                 \|/                
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                  |                 
   |                 /\                 
   |                /  \                
   |               /    \               
   |                                    
   |                                    
   |                                    
   |_________________________________                                     

"""]
    
    hm=print(picture[x])
    return (hm)

def replay():
    """This function is called when the user wants to play the game again, after win"""
    
    print(f"Do you want to play this game again, {name}?\n 1)yes\n 2)no\n")
    play_again=input(f"<Enter your response,{name} 1 or 2:\t >") 
    # if-else condition used to suit the users need
    if play_again=="1" or play_again=="one":
        startpath()
    elif play_again=="2" or play_again=="two":
        print("Thank you for playing!")
    else:
        print("Invalid entery. Enter either 1 or 2")
        replay()
    
def startpath():
    """ This is the beginning function used for defining level1 of the game."""
    
    print("_"* 100)
    print("*"* 100)
    play=input(f"Are you for sure, you want to play this game, {name}?\n 1) yes\n 2)no\n")
    # Nested if-else condition is used to adapt to the users need (to play or not)
    # If the user agrees to play which path he would like to choose.
    if play=="1" or play=="one":
        print("_"* 100)
        print("*"* 100)
        print("""
                Wonderful! You are starting Level 1 of the game..
        
                 You started the adventure few days ago in this island. You are
                 lost now, tired in the forest, fighting, trying to survive 
                 and find a way out. 
                 
                 Walking.. Walking you reach a junction leading to two paths
                 
                 You are expected to choose either of the path to reach a safe
                 destination. 
                 
                 You hear a voice in the wilderness speak to you.
                 "You cannot run away or pass any of these paths without completing
                  a task"
                 
                 "First path is the path of shadows, this path has vivid colours
                 which creates a hallucinating effect. 
                 
                 Second path is the path filled with wild animals"
                 
                 """)
        input(f"<Press enter to continue, {name}>")
        interest = input(f"""
                        Choose a path:
                        
                        1) Select 1 for Path of vivid Colours
                        2) Select 2 for Path of wild animals
                        """)
        
        print("_"* 100)
        print("*"* 100)
        interest=interest.lower()
        
        if interest =="1" or interest == "one":
            print ("""
                    Wow! Seems like you are upto taking up the challenge of 
            
                    not falling a prey to the mysterious colours. 
                      
                      
                          Welcome to the 'Path of vivid colours'! 
                      
                      """)
            input(f"<Please press enter to continue, {name}>")
            
            print("""
                    
                    You are expected to guess which is the colour you will 
                    see in your path, inorder to pass the path safely.
                  
                  """)
            
            input(f"<Please press enter to continue, {name}>")
            
            # Using RANDOM function to choose a word in the category colours randomly.
            listof_colours=["red","blue","green","pink"]
            global selection
            selection=random.choice(listof_colours)
            
            #Calling main function BODY_1 to execute level1 of the game.
            body_1(selection)

            
        elif interest =="2" or interest == "two":
                 
            print("""
                    
                    Wow you are a risk taker! Dont become a prey to those wild beasts.
            
                     
                          Welcome to the 'Path filled with wild animals'!
                     
                  """)
            input(f"<Please press enter to continue, {name}>")
            
            print("""
                    
                    You are expected to guess which is the wild beast you will 
                    see in your path, inorder to survive the path safely.
                     
                 """)
            
            input(f"<Please press enter to continue, {name}>")
            
            # Using RANDOM function to choose a word in the category animals randomly
            listof_animals=["tiger","lion","bear","snake"]
            selection=random.choice(listof_animals)
            
            #Calling main function BODY_1 to execute level1 of the game.
            body_1(selection)
        
        
        else:
            
            print("Invalid answer. Type either 1 or 2")
            startpath()
    
    
    elif play=="2" or play == "two" :
        
        print("Thank you for playing!")
    
    
    else :
        
        print("Invalid input, press 1 or 2")       
        startpath()
        
def fail():
    print("You've failed!")
    print("What do you like to do next?\n 1) Leave the game\n 2)Restart the game from Level1\n ") 
    input('<Press enter to continue>\n')
    decision=input("Enter either 1 or 2")
    if decision=="1":
        print ("Thanks for playing! See you later!")
        exit(0)
    elif decision=="2":
        print ("Yay! Lets begin our adventure again!")
        startpath()
    else:
        print("Invalid Input. Enter a valid input")
        fail()
def repeat(select_common):
    """This function executes the common logical functions taking place in all three rounds (guessing word)"""
    
    blankspace=[]
    actual_word=[]
    guess_word=[]
    user_guess=[]
    used=[]
    
    #Creating a list called blankspace using condition (FOR loop) 
    #list created using the length of randomly chosen word.
    for letters in select_common:
        blankspace.append("_")
        
    print("_"* 100)
    print("*"* 100)    
    print("Guess the following:\n")
    input(f"<Please press Enter to Continue, {name}>")
    
    #Only 8 chances are given, as the hangman function has 8 figures in the list
    print("You are given only 8 guesses!\n")
    
    print(str(blankspace).strip("[]"))
    print("\n")
    print("*"* 100)
    print("_"* 100)
    
    guess_word=blankspace.copy()
    
    #splitting the passed word(as argument) into characters
    def split(select_common): 
        return [char for char in select_common] 
    #assigning the list containing split words to variable ACTUAL_WORD
    actual_word=(split(select_common))
    
    used=(split(select_common))
    
    attempt=8
    #Calling function HANGMAN to show initial stage
    graph=hangman(0)
    j=(attempt-(attempt-1))-1
    
    #Checking for all the letters in the word with the user's guess
    #WHILE loop runs until user guessed the word or run out of guesses
    while actual_word!=blankspace and attempt>0 :
        
        print("*"* 100)
        print("_"* 100)
        
        g=input(prompt="Guess a letter from a-z: \n")
        guess=g.lower()
        count=0
        ct=0
        #Using Nested If-Else condition to check if the letter guessed is in the word.
        #If-Else is used to also check if the letter user used has been guessed once.
        if guess in actual_word:
            
            if guess not in used:
                print(f"The letter has been already guessed. No more letter {guess} \n")
                continue
            #FOR loop is used to check whether the guess corresponds to any position in the word(list)
            for z in range(len(actual_word)):
                if actual_word[z]==guess and guess in used:
                    blankspace[z]=guess
                    user_guess.append(guess)
                    used.remove(guess)
            
            g=hangman(j)
            print("Thats a correct guess!")
            print(str(blankspace).strip("[]"))
            
            #If the user guessed the word right, it exits the function and returns value to main body
            if actual_word==blankspace:
                return(blankspace)
            #function used to give user the chance to view the answer
            def see_answer(c):
                print("_"* 100)
                print("*"* 100)
                show_ans=input("Do you want to see answer? \n1) yes\n2) no")
                #if-else condition used to check if user wants to see answer
                if show_ans=="1":
                    print (f"the answer is {actual_word}\n")
                    blankspace=actual_word
                    c=c+1
                    return c
                elif show_ans=="2":
                    print("lets continue!\n")
                else:
                    print("Invalid input.Kindly select '1' or '2' as answer\n" )
                    ct=see_answer(c)
                    return ct
                
            if count==0:                
                count=see_answer(count)
            if count==1 or ct==1:
                fail()
                break
                
        else:
            attempt=attempt-1
            j=j+1
            print("_"* 100)
            print("*"* 100)
            g=hangman(j)
            #If- else statement used to check the number of attempts remaining for user
            if attempt==1:
                print(f"""
                        
                        You have only {attempt} chance remaining
                      
                      """)
            elif attempt>1:
                print(f"""
                                    Wrong guess try again. 
                    You have {attempt} attempts,remaining to guess the right alphabets.
                        
                      """)
            elif attempt==0:
                print(f"\nYou have {attempt} attempts.\n")
                fail()
                
            print(str(blankspace).strip("[]"))

def body_1(selected_var): 
    """Main function called for executing level1 of the game"""
   
    #splitting the passed word(as argument) into characters
    def split(selected_var): 
        return [char for char in selected_var] 
    
    actual_word=(split(selected_var))
    c=repeat(selected_var)
    
    #If statement used, if the selected word is equal to the guess of the user. 
    if actual_word==c:
        print("_"* 100)
        print("*"* 100)
        print(f"""
                        The guess was correct!
                      The answer is: {selected_var}
               
               """) 
        print("""
                
                    You can enter your path and walk safely!
            
              """) 
        print("_"* 100)
        print("*"* 100)
        cont_level2()
        
        
def cont_level2():
    """Function called to check if user want to continue playing the game and proceed to level2"""
    
    # if-else condition is used to adapt to the users need (to play or not)
    print(f"Do you want to continue to level 2?\n 1)yes\n 2)no\n")
    play1=input(f"<Enter your response,{name} 1 or 2:\t >")     
    if play1=="1" or play1=="one":
        print("You will proceed to level2")
        level_2()
            
    elif play1=="2" or play1=="two":
        print("Thank you for playing!")
            
    else:
        print("Invalid input, press 1 or 2")       
        cont_level2()


def level_2():
    """This is the beginning function used for defining level2 of the game"""
    
    
    # If- else condition, if the user agrees to play which path he would like to choose.
    print("""
          Great job on successfully completing your first path and being alive! 
          You have reached at the end of your path and as you walk ahead you see
          an old man, blocking the path to two big caverns. 
          
          The aged man screams: 
              'Behold!, you who trespasses this land. I am Debasish, the wisest 
               of all. Inorder to pass me and choose a cavern, you need to be aware
               of what lies ahead of you.'
          He points out to two caverns and continues:
              'The first cavern takes you to the sea in 4 days, but it is filled
               with a poisonous fruit. You will have to survive on it for 4 days.
               
               The second cavern takes you to the sea in a day, but has many annoying
               monkeys who will throw vegetables at you.'
               
              'No matter which path you take you need to answer a question regarding 
              each cavern. You have 8 chances to guess the right letters associated 
              to the answer.'
              
            """)
    input(f"<Press enter to continue, {name}>")
    interest = input(f"""
                        Choose a path:
                        
                        1) Select 1 for Cavern of poisonous fruit
                        2) Select 2 for Cavern of monkey throwing vegetables
                        
                        """)
        
    print("_"* 100)
    print("*"* 100)
    interest=interest.lower()
    
    if interest =="1" or interest == "one":
        
        print ("""
                Seems like you will take 4 days to reach the sea. 
                        Good luck not falling sick!     
                      
               """)
        input(f"<Please press enter to continue, {name}>")
            
        print("""
                You are expected to guess which is the least poisonous fruit you
                will see in your path for consumption, inorder to pass the path safely.
                   
                        Welcome to the 'Cavern of poisonous fruit'! 
                   """)
            
        input(f"<Please press enter to continue, {name}>")
        
        # Using RANDOM function to choose a word in the category fruits randomly.
        listof_fruits=["orange","pear","apple","banana"]
        selection1=random.choice(listof_fruits)
        
        #Calling main function BODY_2 to execute level2 of the game.
        body_2(selection1)

    elif interest =="2" or interest == "two":
        
        print ("""
                Seems like you will take 1 days to reach the sea. 
                        Good luck not gtting hurt!     
                      
               """)
        input(f"<Please press enter to continue, {name}>")
            
        print("""
                You are expected to guess which is the vegetable the monkeys will 
                attack you with in your path, inorder to pass the path safely.
                   
                        Welcome to the 'Cavern of annoying monkeys'! 
                   """)
            
        input(f"<Please press enter to continue, {name}>")
        
        # Using RANDOM function to choose a word in the category vegetables randomly.
        listof_vegetables=["carrot","tomato","potato","eggplant"]
        selection1=random.choice(listof_vegetables)
        
        #Calling main function BODY_2 to execute level2 of the game.
        body_2(selection1)
        
    else:
            
        print("Invalid answer. Type either 1 or 2")
        level_2()

def body_2(select_var2):
    """Main function called for executing level2 of the game"""
    
    #splitting the passed word(as argument) into characters
    def split(select_var2): 
        return [char for char in select_var2]     
    actual_word=(split(select_var2))
    c=repeat(select_var2)
    
    #If statement used, if the selected word is equal to the guess of the user.
    if actual_word==c:
        print("_"* 100)
        print("*"* 100)
        print(f"""
                     The guess was correct!
                  The answer is: {select_var2}
             
              """) 
        print("""
               
               You can walk into the Cavern and reach the seashore!
              
              """)  
        print("_"* 100)
        print("*"* 100)
        cont_level3()

def cont_level3():
    """Function called to check if user want to continue playing the game and proceed to level3"""
    
    # if-else condition is used to adapt to the users need (to play or not)
    print("Do you want to continue to level 3?\n 1)yes\n 2)no\n")
    play2=input(f"<Enter your response,{name} 1 or 2:\t >")    
    if play2=="1" or play2=="one":
        print("You will proceed to level3")
        level_3()
            
    elif play2=="2" or play2=="two" :
        print("Thank you for playing!")
            
    else:
        print("Invalid input, press 1 or 2") 
        cont_level3()
def level_3():
    """This is the beginning function used for defining level3 of the game"""
    
    print("_"* 100)
    print("*"* 100)
    print("""
          Great job on successfully passing through the cavern and being alive! 
          You have reached at the sea shore and as you walk ahead you see
          a boat and a man standing next to it. 
          
          You approach the boat and ask the man if there is a way out of this island.
          
          The man replied:
              'There is no way out except through the deep sea.'
              
          You asked if he could take you along with him away from this deserted island. 
          
          The man says:
              'I shall take you along with me if, and only if, you can tell which 
               country this boat is heading to and the capital of the country'
          
          He points out to distant sea and continues:
              'I have sufficient food stored for our journey to that land. It 
               takes us approximately 60 days to reach there.'
          
          You need to get out of the island and have no other way out, except this boat.
              
            """)
    input(f"<Press Enter to continue, {name}>")
         
    print("""
          In this level you are expected to: 
            1) Identify the Country 
            2) Identify the capital of the guessed country
           
          """)
    
    input(f"<Press Enter to Continue, {name}>")
    
    # Using RANDOM function to choose a country and its capital randomly.
    listof_country_capital=[["france","paris"],["italy","rome"],["canada","ottawa"],["india","delhi"]]
    select =random.choice(listof_country_capital)
    str1 = ' '.join(select)
    s=str1.split(" ")
    select1=s[0]
    select2=s[1]
    
    #Calling main function BODY_3 to execute level3 of the game.
    body_3(select1, select2)

def body_3(sel1,sel2):
    """Main function called for executing level3 of the game"""
        
    c=repeat(sel1)
    
    #Joining letters in list to form string
    str1 = ''.join(c)
    
    #Nested-If statement used, if the selected word is equal to the guess of the user
    if sel1==str1:
        print(f"""
               You have guessed the correct country.
                     The country is {str1}
               
              """)
        c2=repeat(sel2)
        str2=''.join(c2)
        if sel2==str2:
            print(f"""
                    You have guessed the capital right, Hurray!
                    
                  """)
            print(f"""
                  You survived!! You can successfully exit out of this 
                  mysterious island and be at peace. Safe journey!
                  
                  """)
            input(f"<Please enter to continue, {name}>")
            print("""
                      You won the challenge! Congratulations!
                  """)
            print("_"* 100)
            print("*"* 100)
            replay()
        else:
            fail()
    else:
        fail()
starting()
# Out:
#
#
# Introduction:
#
# The game is called 'Will you be able to survive this adventure?'.This game is an
# adapted version of the paper based game called 'Hangman'. The game is simple
# and requires you to guess the letters of the word and reveal it inorder to
# clear each level without dying. You will be given 8 chances to guess the word
# right.For every wrong guess a part of body is drawn and upon losing all your
# chances will be lost and you will see a man hanged, in other words it means
# you lost your adventure.
#
# A simple guideline will be to start the game by guessing for vowels
# (a, e, i, o, u), and then proceed guessing other letters.
#
#     The game has 3 levels
#     The person is lost in an island
#     a)Level 1 Choose a dangerous path out of two
#     b)Level 2 Choose a challenging cavern out of two
#     c)Level 3 Identify the country and its capital inorder to escape the island safely
#
# Upon completion of the levels you shall win this game
#
#
# ...
